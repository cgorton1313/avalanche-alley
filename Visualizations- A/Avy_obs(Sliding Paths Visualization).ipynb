# %% [markdown]
# # What paths slide the most? Which ones hit the rail and/or highway?

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

avyobs= pd.read_pickle('/Users/ashleyshell/Documents/GitHub.nosync/avalanche-alley/data-prep/pkl/avy_obs.pkl')

# %%
pd.set_option('display.max_columns', None)
avyobs
# Out:
#        avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1        SHED10 2012-03-26  12:45:00     stein_01     WS           5.0
# 2      PATH1163 2012-03-16  08:30:00     stein_01      U           5.0
# 3         CURLY 2012-03-16  08:34:00     stein_01      U           5.0
# 4        SHED10 2012-03-10  14:50:00     stein_01     WL           5.0
# 5      INFINITY 2012-03-10  14:54:00     stein_01      L           5.0
# ...         ...        ...       ...          ...    ...           ...
# 504     SHED07W 2022-03-01  05:04:00     clark_01     SS           5.0
# 505     AP1163H 2022-03-23  13:30:00     clark_01     WL           5.0
# 506      SHED10 2022-03-23  13:30:00     clark_01     WL           5.0
# 507     MCAMSER 2022-03-23  18:00:00     clark_01     HS           5.0
# 508    PATH1163 2022-03-27  14:35:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 1            NL             R1              D1.5           O       B        R
# 2            NU              U                D2           U       U        U
# 3            NU              U                D1           U       U        U
# 4           NaN             R2                D1           I       M        R
# 5             N             R2                D1           I       T        C
# ...         ...            ...               ...         ...     ...      ...
# 504          NC             R2                D2           I       T        L
# 505          NU             R1              D1.5           O       T        U
# 506           N             R2                D2           O       T        C
# 507          NC             R3                D3           O       T        C
# 508           N             R1                D2           O       T        L
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 1                0          0       NaN            0          0
# 2                0          0       NaN            0          0
# 3                0          0       NaN            0          0
# 4                0          0       NaN            0          0
# 5                0          0       NaN            0          0
# ...            ...        ...       ...          ...        ...
# 504             38       2015         E         1760        255
# 505              0       1830        SW         1460        370
# 506             40       2075        SE         1646        429
# 507             40       2195        SE         1790        405
# 508             40       2135        SE         1400        735
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 1                  0          0          0           0            TK
# 2                  0          0          0           0            TK
# 3                  0          0          0           0            TR
# 4                  0          0          0           0            TK
# 5                  0          0          0           0            TK
# ...              ...        ...        ...         ...           ...
# 504                0          0          0           0            TK
# 505                0          0          0           0            TR
# 506                0          0          0           0            TK
# 507              245        150         40          95            MR
# 508                0          0          0           0            MR
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 1                NaN         NaN        NaN     False         0.0         0.0
# 2                NaN         NaN        NaN     False         0.0         0.0
# 3                NaN         NaN        NaN     False         0.0         0.0
# 4                NaN         NaN        NaN     False         0.0         0.0
# 5                NaN         NaN        NaN     False         0.0         0.0
# ...              ...         ...        ...       ...         ...         ...
# 504                -           U          U     False         0.0         0.0
# 505                -           U          W     False         0.0         0.0
# 506                -           U          W     False         0.0         0.0
# 507                -           U          U     False         0.0         0.0
# 508                -           U          W     False         0.0         0.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d  \
# avrid
# 1        False        0.0        0.0
# 2        False        0.0        0.0
# 3        False        0.0        0.0
# 4        False        0.0        0.0
# 5        False        0.0        0.0
# ...        ...        ...        ...
# 504      False        0.0        0.0
# 505      False        0.0        0.0
# 506      False        0.0        0.0
# 507      False        0.0        0.0
# 508      False        0.0        0.0
#
#                                                avcomment edcr_user  \
# avrid
# 1      Wet slab released on SE aspect @ 5400 feet (16...        ed
# 2      Wet debris ran 2/3 path in main path to 4700 f...        ed
# 3      Terminus at canyon floor elevation.\r\n\r\nDeb...        ed
# 4                                                   D1.5        ed
# 5                                        D1.5- 1/2 Path.        ed
# ...                                                  ...       ...
# 504    Slab not observed until March 17th during a sk...      Adam
# 505                                                  NaN      Adam
# 506                            Obs on Mar. 24th from Hwy      Adam
# 507    Obs on Mar. 24th from Hwy. Could not see runou...      Adam
# 508                          Obs. on Mar. 28th from Hwy.      Adam
#
#                 edcr_time       edcr_ip eded_user            eded_time eded_ip
# avrid
# 1     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00     NaN
# 2     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00     NaN
# 3     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00     NaN
# 4     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00     NaN
# 5     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00     NaN
# ...                   ...           ...       ...                  ...     ...
# 504   2022-03-17 21:17:04    10.30.72.4       NaN  0000-00-00 00:00:00     NaN
# 505   2022-03-23 21:32:42    10.30.72.4       NaN  0000-00-00 00:00:00     NaN
# 506   2022-03-28 16:30:35    10.30.72.4       NaN  0000-00-00 00:00:00     NaN
# 507   2022-03-28 16:34:43    10.30.72.4       NaN  0000-00-00 00:00:00     NaN
# 508   2022-03-28 16:37:03    10.30.72.4       NaN  0000-00-00 00:00:00     NaN
#
# [491 rows x 38 columns]

# %%
paths = avyobs.avpathid.value_counts()
paths
# Out:
# PATH1163      105
# INFINITY       58
# SHED10         35
# SHED07W        28
# SHED11         23
# JAKES          20
# SHED07E        17
# SHED08         16
# JAVA           15
# AP1163H        14
# GRIZZLY        13
# BURNOUT        10
# UMBRELLA       10
# LARRY          10
# SHED09L         8
# CURLY           8
# SHED107         7
# SHED05          7
# SHED09          6
# GOATLICK        6
# JAVAGA          5
# IBEAM           5
# TestSlope2      5
# MCAMSER         5
# SECOND          5
# SHED07          4
# MSHLDS          4
# CB1160          4
# TestSlope3      4
# SHED06          4
# SHED04D         3
# BROKEN          3
# CB1164          3
# AP1183          2
# CB1159          2
# FRYPAN          2
# SHED12          2
# TestSlope1      2
# ELKFENCE        2
# NOSHED          1
# MO              1
# CB1160-3        1
# 1155CUTBAN      1
# ELKMTN          1
# ESSEXMTN        1
# HANGINGNO       1
# MCAMNF          1
# SHED07WP        1
# Name: avpathid, dtype: int64

# %%
pathtop = paths.head(5)
pathtop
# Out:
# PATH1163    105
# INFINITY     58
# SHED10       35
# SHED07W      28
# SHED11       23
# Name: avpathid, dtype: int64

# %%
colors = ['#FEC8D8','#F2ECCE','#FCFADE','#E0BBE4','#A6E1EA']
explode = (0.1 ,0, 0, 0, 0)
avalanch = pathtop.plot.pie(title = "Which Paths Had The Most Avalanches", y='pathtop', figsize=(12, 12),autopct='%1.1f%%', colors = colors, explode = explode, shadow = True)

# %%
sns.set(rc={'figure.figsize':(60,40)})
sns.barplot(x = 'avpathid',
            y = avyobs.index,
            hue = 'deb_hwy',
            data = avyobs)
# Out:
# <AxesSubplot:xlabel='avpathid', ylabel='avrid'>

# %%
avyobs.loc[avyobs.deb_hwy == True]
# Out:
#        avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 232       IBEAM 2014-03-06  05:30:00     stein_01     SS           5.0
# 234    GOATLICK 2014-03-06  07:00:00     stein_01     SS           5.0
# 260    PATH1163 2017-02-09  08:30:00     stein_01     SS           5.0
# 263      NOSHED 2017-02-07  12:30:00     stein_01     SS           1.0
# 291      AP1183 2017-02-07  03:30:00     stein_01     SS           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 232          NU             R2                D3           O       T        R
# 234           N             R3                D4           O       T        C
# 260           N             R3                D3           I       M        L
# 263          AX             R4                D2           G       T        C
# 291           N             R3                D3           O       T        C
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 232             40       2242         N         1230       1012
# 234             35       2212         N         1152       1060
# 260             40       2028        SE         1236        792
# 263             38       1353         N         1235        118
# 291             39       1697         N         1030        667
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 232              160        150        100         125            TK
# 234              800        120        120         120            BR
# 260               45        120         90         105            BR
# 263               30         90         60          75             U
# 291              364        120        300         210            BR
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 232                -           U          W     False         0.0         0.0
# 234                -           U          W     False         0.0         0.0
# 260                -           U          D      True       100.0         1.5
# 263               BP          3F          D      True        30.0         1.0
# 291                -           -          D      True       120.0         2.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d  \
# avrid
# 232       True       20.0       20.0
# 234       True       30.0       20.0
# 260       True       20.0        0.1
# 263       True       10.0        0.2
# 291       True       30.0        0.1
#
#                                                avcomment edcr_user  \
# avrid
# 232    SS-N-R2-D3-O.\nDebris terminated at Highway el...       Ted
# 234    SS-N-R3-D4-O. Aspect= 240.\nRan full path pass...       Ted
# 260    Natural SS avalanche in Path 1163 triggered na...       Ted
# 263    Triggered with Daisy Bell. Avalanche terminate...       Ted
# 291    1183 avalanche ran at approximately 2230 on 2/...       Ted
#
#                 edcr_time       edcr_ip eded_user            eded_time  \
# avrid
# 232   2016-03-17 11:50:56  72.160.63.46       Ted  2020-06-29 12:25:56
# 234   2016-03-17 11:50:56  72.160.63.46       Ted  2020-06-29 11:52:37
# 260   2017-02-27 15:25:55  139.51.15.20       Ted  2020-06-29 13:13:18
# 263   2017-02-27 15:54:02  139.51.15.22       Ted  2020-06-29 09:58:06
# 291   2017-12-28 13:19:38  139.51.15.19       Ted  2020-06-29 10:33:44
#
#            eded_ip
# avrid
# 232    64.91.61.64
# 234    64.91.61.64
# 260    64.91.61.64
# 263    64.91.61.64
# 291    64.91.61.64

# %%
sns.set(rc={'figure.figsize':(60,40)})
sns.barplot(x = 'avpathid',
            y = avyobs.index,
            hue = 'deb_rail',
            data = avyobs)
# Out:
# <AxesSubplot:xlabel='avpathid', ylabel='avrid'>

# %%
avyobs.loc[avyobs.deb_rail == True]
# Out:
#          avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 39         SHED05 2011-01-16  20:15:00     stein_01     HS           5.0
# 73         SHED05 2009-01-08  13:59:00     stein_01     HS           5.0
# 89         SHED08 2008-12-29  12:25:00     stein_01     SS           5.0
# 143        SHED08 2006-02-25  12:55:00     stein_01     SS           1.0
# 221       SHED07E 2014-03-09  17:06:00     stein_01     WS           5.0
# 233       SHED07W 2014-03-06  00:05:00     stein_01     SS           5.0
# 257       SHED107 2017-02-06  10:00:00     clark_01     SS           5.0
# 259       SHED07E 2017-02-06  10:15:00     clark_01     SS           5.0
# 260      PATH1163 2017-02-09  08:30:00     stein_01     SS           5.0
# 262         JAKES 2017-01-18  12:35:00     stein_01      L           5.0
# 263        NOSHED 2017-02-07  12:30:00     stein_01     SS           1.0
# 291        AP1183 2017-02-07  03:30:00     stein_01     SS           5.0
# 292      UMBRELLA 2017-02-06  03:30:00     stein_01     SS           5.0
# 294        CB1164 2017-02-06  02:00:00     stein_01      U           5.0
# 295         JAKES 2017-02-06  02:00:00     stein_01      U           5.0
# 296      CB1160-3 2017-02-06  02:00:00     stein_01      U           5.0
# 297        CB1160 2017-02-06  02:00:00     stein_01      U           5.0
# 298        CB1159 2017-02-06  02:00:00     stein_01      U           5.0
# 299        CB1160 2017-02-06  02:00:00     stein_01      U           5.0
# 302      INFINITY 2017-12-30  09:00:00     clark_01     SS           5.0
# 303    1155CUTBAN 2017-02-06  18:12:00     stein_01     SS           5.0
# 305      UMBRELLA 2018-02-07  14:00:00     stein_01     WS           5.0
# 343         JAKES 2019-03-18  11:00:00     clark_01     WL           5.0
# 386      UMBRELLA 2020-03-11  10:30:00     clark_01     WL           5.0
# 419       BURNOUT 2017-02-06  00:33:00     clark_01     SS           5.0
# 412         JAKES 2017-02-07  12:35:00     stein_01     SS           1.0
# 413         JAKES 2017-02-07  12:36:00     stein_01     SS           1.0
# 414         JAKES 2017-02-07  12:37:00     stein_01     SS           1.0
# 415      UMBRELLA 2017-02-07  12:15:00     stein_01     SS           1.0
# 416       BURNOUT 2017-02-07  12:07:00     stein_01     SS           1.0
# 424       SHED07E 2008-12-30  09:50:00     stein_01     SS           5.0
# 429      UMBRELLA 2009-01-08  05:00:00     clark_01     SS           5.0
# 465        SECOND 2021-02-21  20:30:00     clark_01     SS           5.0
# 466        JAVAGA 2021-02-22  14:20:00     clark_01     SS           5.0
# 468       SHED07W 2021-02-23  11:03:00     clark_01     HS           5.0
# 471       SHED07E 2021-02-24  12:42:00     clark_01     HS           1.0
# 480        SECOND 2022-01-08  00:30:00     clark_01     SS           5.0
# 483      SHED07WP 2022-01-13  15:00:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 39            N             R4                D4           O       T        C
# 73            N              U                D3           G       T        U
# 89            N             R3                D3           G       U        L
# 143          AE             R3                D3           U       M        C
# 221          NC             R2              D2.5           O       M        L
# 233           N             R3              D3.5           O       T        R
# 257          NU             R2                D3           U       U        U
# 259          NU             R3                D3           U       T        C
# 260           N             R3                D3           I       M        L
# 262           N             R3                D2           G       T        C
# 263          AX             R4                D2           G       T        C
# 291           N             R3                D3           O       T        C
# 292           N             R4              D1.5           I       U        U
# 294           N              U                 U           U       U        U
# 295           N              U                 U           U       U        U
# 296           N              U                 U           U       U        U
# 297           N              U                 U           U       U        U
# 298           N              U                 U           U       U        U
# 299           N              U                 U           U       U        U
# 302           N             R4                D3           U       T        R
# 303           N              U                 U           U       U        U
# 305          NU             R2                D1           S       M        C
# 343          NU             R4              D2.5           O       T        C
# 386          NU             R1                D1           I       M        C
# 419          NU              U              D2.5           U       U        U
# 412          AX             R2              D1.5           S       T        R
# 413          AX             R2              D1.5           S       T        C
# 414          AX             R2              D1.5           S       T        L
# 415          AX             R2                D1           S       T        C
# 416          AX             R1                D1           S       M        C
# 424          NU             R3              D2.5           G       T        C
# 429          NU              U              D1.5           U       U        U
# 465          NU              U                D2           U       M        C
# 466           N             R3              D2.5           O       M        L
# 468          NC             R3                D3           O       T        C
# 471          AH             R4                D3           O       T        C
# 480          NU             R4                D2           O       T        C
# 483          NU              U              D1.5           I       U        U
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 39               0          0         N            0          0
# 73               0          0         N            0          0
# 89               0          0         N            0          0
# 143              0       1870         E         1333        537
# 221             38       1818         N         1318        500
# 233             35       1924         N         1327        597
# 257              0       1796         N         1257        539
# 259             40       1882         N         1294        588
# 260             40       2028        SE         1236        792
# 262             40       1588         N         1265        323
# 263             38       1353         N         1235        118
# 291             39       1697         N         1030        667
# 292              0          0         S         1353          0
# 294              0          0         N         1250          0
# 295              0          0         N         1265          0
# 296              0          0         N         1356          0
# 297              0          0         N         1364          0
# 298              0          0         N         1385          0
# 299              0          0         N         1364          0
# 302             38       1866         S         1322        544
# 303              0          0         N            0          0
# 305              0       1380         N         1347         33
# 343              0       1524         S         1280        244
# 386              0       1400        SE         1355         45
# 419              0          0         N            0          0
# 412              0       1527         N         1303        224
# 413              0       1527         S         1303        224
# 414              0       1527         S         1303        224
# 415              0       1386        SE         1347         39
# 416              0       1515         N         1370        145
# 424              0       1920         N         1340        580
# 429              0          0         N            0          0
# 465              0       1525         S         1310        215
# 466             40       1280         E         1220         60
# 468              0       2042         E         1310        732
# 471              0       1860        SE         1310        550
# 480              0       1646        SE         1297        349
# 483              0       1524        SE         1340        184
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 39                 0          0          0           0            BR
# 73                 0          0          0           0            BR
# 89                 0          0          0           0            BR
# 143               60        180         90         135            BR
# 221               60         90         60          75            BR
# 233              360        120        120         120            MR
# 257                0          0          0           0            MR
# 259               70         90         90          90            TR
# 260               45        120         90         105            BR
# 262                0          0          0           0             U
# 263               30         90         60          75             U
# 291              364        120        300         210            BR
# 292                0         30        100          65             U
# 294                0          0          0           0             U
# 295                0          0          0           0             U
# 296                0          0          0           0             U
# 297                0          0          0           0             U
# 298                0          0          0           0             U
# 299                0          0          0           0             U
# 302                0          0          0           0            BR
# 303                0          0          0           0             U
# 305               20         20         10          15             U
# 343                0          0          0           0            BR
# 386                0          0          0           0             U
# 419                0          0          0           0            BR
# 412               20         60         30          45             -
# 413               20         60         30          45             -
# 414               20         30         30          30             -
# 415               20         30         15          23             U
# 416               15         30         15          23             U
# 424                0          0          0           0             U
# 429                0          0          0           0             U
# 465                0          0          0           0            BR
# 466              100        150         30          90             U
# 468              500        300        100         200            BR
# 471              300        250        100         175            BR
# 480              100        130         25          78            BR
# 483                0          0          0           0             U
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 39                 -           U          U      True        30.0         0.2
# 73                 -           U          U      True        30.0         8.0
# 89                 -           U          U      True         0.0         0.0
# 143                -           U          D      True        20.0         0.5
# 221                -          2F          W      True         0.0         0.0
# 233                -           U          W      True        30.0        20.0
# 257                -           U          U      True        20.0         0.2
# 259                -           U          D      True        30.0         1.5
# 260                -           U          D      True       100.0         1.5
# 262               BP           U          W      True        10.0         0.8
# 263               BP          3F          D      True        30.0         1.0
# 291                -           -          D      True       120.0         2.0
# 292               BP           U          U      True        40.0         2.0
# 294               BP           U          U      True         0.0         0.0
# 295               BP           U          U      True         0.0         0.0
# 296                -           U          U      True         0.0         0.0
# 297                -           U          U      True         0.0         0.0
# 298                -           U          U      True         0.0         0.0
# 299                -           U          U      True         0.0         0.0
# 302                -           U          D      True       130.0         0.2
# 303               BP           U          D      True         0.0         0.0
# 305               BP           U          M      True         5.0         1.0
# 343                -           U          W      True         4.0         0.2
# 386               BP           U          W      True         7.0         0.7
# 419                -           U          U      True         0.0         0.0
# 412               BP           U          D      True        20.0         0.5
# 413               BP           U          D      True        20.0         1.0
# 414               BP           U          D      True        20.0         0.5
# 415               BP           U          D      True        20.0         1.0
# 416               BP           U          D      True        30.0         0.5
# 424                -           U          U      True         0.0         0.0
# 429               BP           U          U      True         0.0         0.0
# 465                -           -          D      True        10.0         1.5
# 466               BP           U          U      True        50.0         2.0
# 468                -          3F          D      True        80.0         2.0
# 471                -          3F          D      True       100.0         3.0
# 480                -           U          U      True        20.0         4.0
# 483               BP           U          W      True        15.0         2.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d  \
# avrid
# 39       False        0.0        0.0
# 73       False        0.0        0.0
# 89       False        0.0        0.0
# 143      False        0.0        0.0
# 221      False        0.0        0.0
# 233      False        0.0        0.0
# 257      False        0.0        0.0
# 259      False        0.0        0.0
# 260       True       20.0        0.1
# 262      False        0.0        0.0
# 263       True       10.0        0.2
# 291       True       30.0        0.1
# 292      False        0.0        0.0
# 294      False        0.0        0.0
# 295      False        0.0        0.0
# 296      False        0.0        0.0
# 297      False        0.0        0.0
# 298      False        0.0        0.0
# 299      False        0.0        0.0
# 302      False        0.0        0.0
# 303      False        0.0        0.0
# 305      False        0.0        0.0
# 343      False        0.0        0.0
# 386      False        0.0        0.0
# 419      False        0.0        0.0
# 412      False        0.0        0.0
# 413      False        0.0        0.0
# 414      False        0.0        0.0
# 415      False        0.0        0.0
# 416      False        0.0        0.0
# 424      False        0.0        0.0
# 429      False        0.0        0.0
# 465      False        0.0        0.0
# 466      False        0.0        0.0
# 468      False        0.0        0.0
# 471      False        0.0        0.0
# 480      False        0.0        0.0
# 483      False        0.0        0.0
#
#                                                avcomment edcr_user  \
# avrid
# 39     HS-N-R4-D3.5-O.  85% SZ.  This was a rain/snow...   Steiner
# 73     backfilled snowshed 30' height 100' linear - a...       NaN
# 89     8 foot crown, path filled and debris over the ...       NaN
# 143    Explosives triggered avalanche.  2006-02-25 mi...       NaN
# 221    Released as a SS at rain line about half way d...       Ted
# 233    SS-N-R3-D3+-O.  Avg. Aspect= 180\nTerminus con...       Ted
# 257                         Terminated on Shed 10.7 roof       Ted
# 259    Terminated in runout below Shed 7.  Climbing l...       Ted
# 260    Natural SS avalanche in Path 1163 triggered na...       Ted
# 262    Wet, loose avalanche.  Covered Main 1- Inside ...       Ted
# 263    Triggered with Daisy Bell. Avalanche terminate...       Ted
# 291    1183 avalanche ran at approximately 2230 on 2/...       Ted
# 292    This avalanche released in steep rock band tha...       Ted
# 294    Time is approximate. Debris fully across main ...       Ted
# 295       Time is approximate. Debris across both mains.       Ted
# 296    Time is approximate. Debris fully across main ...       Ted
# 297    Time is approximate. Debris fully across main ...       Ted
# 298           Time is approximate. Debris across Main 1.       Ted
# 299       Time is approximate. Debris across both mains.       Ted
# 302    12/30/17: Infinity Path ran at approximately 0...       Ted
# 303    Dark hours avalanche. Debris deposited on both...       Ted
# 305    Did not cause slide fence damage or delay any ...       Ted
# 343    Likely ran PM 3/17. Two small fingers of debri...      Adam
# 386    Reported by a westbound train at 1145. Debris ...      Adam
# 419    Dark hours avalanche. Debris covered both Main...       NaN
# 412    Ignition 1 of 3. Debris terminated on grade an...       Ted
# 413    Ignition 2 of 3 in Jake's. Debris terminated o...       Ted
# 414    Ignition 3 of 3.  Terminated on grade. Debris ...       Ted
# 415      Debris terminated on the grade covering Main 1.       Ted
# 416      Debris terminated on the grade covering Main 1.       Ted
# 424                       Path filled, debris over shed.      Adam
# 429           Debris terminated at rail grade elevation.      Adam
# 465    Many details lacking for this avalanche. Possi...      Adam
# 466    Debris stopped at slide fence with no debris a...      Adam
# 468    Reported by track inspector shortly after 1100...      Adam
# 471    Triggered by one 5# charge. Debris ran over sh...      Adam
# 480    Slide fence indication and then reported by He...      Adam
# 483    Buried Main 1 and stopped an east-bound train....      Adam
#
#                 edcr_time        edcr_ip eded_user            eded_time  \
# avrid
# 39    2016-03-17 11:50:56             01       Ted  2020-06-29 11:14:49
# 73    2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:58:51
# 89    2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:36:19
# 143   2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:42:33
# 221   2016-03-17 11:50:56   10.173.132.4       Ted  2020-06-29 11:44:57
# 233   2016-03-17 11:50:56   72.160.63.46       Ted  2020-06-29 12:33:15
# 257   2017-02-27 13:45:27   139.51.15.22       Ted  2020-06-29 10:16:11
# 259   2017-02-27 14:18:50   139.51.15.22       Ted  2020-06-29 10:14:50
# 260   2017-02-27 15:25:55   139.51.15.20       Ted  2020-06-29 13:13:18
# 262   2017-02-27 15:45:37   139.51.15.19       Ted  2020-06-29 10:28:52
# 263   2017-02-27 15:54:02   139.51.15.22       Ted  2020-06-29 09:58:06
# 291   2017-12-28 13:19:38   139.51.15.19       Ted  2020-06-29 10:33:44
# 292   2017-12-28 13:20:36   139.51.15.19       Ted  2020-06-29 13:31:05
# 294   2017-12-29 13:56:55   139.51.15.20       Ted  2020-06-29 10:19:56
# 295   2017-12-29 13:59:12   139.51.15.20       Ted  2020-06-29 10:20:35
# 296   2017-12-29 14:05:32   139.51.15.20       Ted  2020-06-29 10:21:19
# 297   2017-12-29 14:08:51   139.51.15.20       Ted  2020-06-29 10:22:27
# 298   2017-12-29 14:14:52   139.51.15.20       Ted  2020-06-29 10:23:41
# 299   2017-12-29 14:20:19   139.51.15.20       Ted  2020-06-29 10:24:12
# 302   2017-12-31 16:22:18   139.51.15.22       Ted  2020-06-29 13:08:44
# 303   2018-01-03 20:15:34   139.51.15.19       Ted  2020-06-29 10:13:01
# 305   2018-02-08 17:34:01   139.51.15.20       Ted  2020-06-29 12:55:59
# 343   2019-03-21 15:14:24   139.51.15.19      Adam  2020-05-31 23:23:59
# 386   2020-03-13 11:20:27   139.51.15.17      Adam  2020-05-31 23:26:20
# 419   2020-05-26 16:36:07  184.166.43.50       Ted  2020-06-29 10:25:11
# 412   2020-05-22 09:23:17    64.91.61.64       Ted  2020-06-29 10:09:34
# 413   2020-05-22 09:26:36    64.91.61.64       Ted  2020-06-29 13:19:21
# 414   2020-05-22 09:35:22    64.91.61.64       Ted  2020-06-29 13:18:48
# 415   2020-05-22 09:46:57    64.91.61.64       Ted  2020-06-29 13:31:53
# 416   2020-05-22 09:50:03    64.91.61.64       Ted  2020-06-29 10:12:12
# 424   2020-05-28 12:50:15   139.51.15.17       Ted  2020-06-29 10:34:37
# 429   2020-05-28 13:08:29   139.51.15.17       Ted  2020-06-29 10:59:56
# 465   2021-03-08 12:10:36     10.30.72.4      Adam  2021-03-08 12:13:55
# 466   2021-03-08 12:20:10     10.30.72.4      Adam  2021-03-08 12:23:07
# 468   2021-03-08 12:46:32     10.30.72.4      Adam  2021-03-08 12:47:03
# 471   2021-03-08 13:11:01     10.30.72.4       NaN  0000-00-00 00:00:00
# 480   2022-01-09 19:57:07     10.30.72.4       NaN  0000-00-00 00:00:00
# 483   2022-01-14 20:00:22     10.30.72.4      Adam  2022-03-08 00:59:39
#
#              eded_ip
# avrid
# 39       64.91.61.64
# 73       64.91.61.64
# 89       64.91.61.64
# 143      64.91.61.64
# 221      64.91.61.64
# 233      64.91.61.64
# 257      64.91.61.64
# 259      64.91.61.64
# 260      64.91.61.64
# 262      64.91.61.64
# 263      64.91.61.64
# 291      64.91.61.64
# 292      64.91.61.64
# 294      64.91.61.64
# 295      64.91.61.64
# 296      64.91.61.64
# 297      64.91.61.64
# 298      64.91.61.64
# 299      64.91.61.64
# 302      64.91.61.64
# 303      64.91.61.64
# 305      64.91.61.64
# 343    184.166.43.50
# 386    184.166.43.50
# 419      64.91.61.64
# 412      64.91.61.64
# 413      64.91.61.64
# 414      64.91.61.64
# 415      64.91.61.64
# 416      64.91.61.64
# 424      64.91.61.64
# 429      64.91.61.64
# 465       10.30.72.4
# 466       10.30.72.4
# 468       10.30.72.4
# 471              NaN
# 480              NaN
# 483    184.166.43.50

# %%
both = avyobs.loc[(avyobs.deb_rail == True) | (avyobs.deb_hwy == True)]
both
# Out:
#          avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 39         SHED05 2011-01-16  20:15:00     stein_01     HS           5.0
# 73         SHED05 2009-01-08  13:59:00     stein_01     HS           5.0
# 89         SHED08 2008-12-29  12:25:00     stein_01     SS           5.0
# 143        SHED08 2006-02-25  12:55:00     stein_01     SS           1.0
# 221       SHED07E 2014-03-09  17:06:00     stein_01     WS           5.0
# 232         IBEAM 2014-03-06  05:30:00     stein_01     SS           5.0
# 233       SHED07W 2014-03-06  00:05:00     stein_01     SS           5.0
# 234      GOATLICK 2014-03-06  07:00:00     stein_01     SS           5.0
# 257       SHED107 2017-02-06  10:00:00     clark_01     SS           5.0
# 259       SHED07E 2017-02-06  10:15:00     clark_01     SS           5.0
# 260      PATH1163 2017-02-09  08:30:00     stein_01     SS           5.0
# 262         JAKES 2017-01-18  12:35:00     stein_01      L           5.0
# 263        NOSHED 2017-02-07  12:30:00     stein_01     SS           1.0
# 291        AP1183 2017-02-07  03:30:00     stein_01     SS           5.0
# 292      UMBRELLA 2017-02-06  03:30:00     stein_01     SS           5.0
# 294        CB1164 2017-02-06  02:00:00     stein_01      U           5.0
# 295         JAKES 2017-02-06  02:00:00     stein_01      U           5.0
# 296      CB1160-3 2017-02-06  02:00:00     stein_01      U           5.0
# 297        CB1160 2017-02-06  02:00:00     stein_01      U           5.0
# 298        CB1159 2017-02-06  02:00:00     stein_01      U           5.0
# 299        CB1160 2017-02-06  02:00:00     stein_01      U           5.0
# 302      INFINITY 2017-12-30  09:00:00     clark_01     SS           5.0
# 303    1155CUTBAN 2017-02-06  18:12:00     stein_01     SS           5.0
# 305      UMBRELLA 2018-02-07  14:00:00     stein_01     WS           5.0
# 343         JAKES 2019-03-18  11:00:00     clark_01     WL           5.0
# 386      UMBRELLA 2020-03-11  10:30:00     clark_01     WL           5.0
# 419       BURNOUT 2017-02-06  00:33:00     clark_01     SS           5.0
# 412         JAKES 2017-02-07  12:35:00     stein_01     SS           1.0
# 413         JAKES 2017-02-07  12:36:00     stein_01     SS           1.0
# 414         JAKES 2017-02-07  12:37:00     stein_01     SS           1.0
# 415      UMBRELLA 2017-02-07  12:15:00     stein_01     SS           1.0
# 416       BURNOUT 2017-02-07  12:07:00     stein_01     SS           1.0
# 424       SHED07E 2008-12-30  09:50:00     stein_01     SS           5.0
# 429      UMBRELLA 2009-01-08  05:00:00     clark_01     SS           5.0
# 465        SECOND 2021-02-21  20:30:00     clark_01     SS           5.0
# 466        JAVAGA 2021-02-22  14:20:00     clark_01     SS           5.0
# 468       SHED07W 2021-02-23  11:03:00     clark_01     HS           5.0
# 471       SHED07E 2021-02-24  12:42:00     clark_01     HS           1.0
# 480        SECOND 2022-01-08  00:30:00     clark_01     SS           5.0
# 483      SHED07WP 2022-01-13  15:00:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 39            N             R4                D4           O       T        C
# 73            N              U                D3           G       T        U
# 89            N             R3                D3           G       U        L
# 143          AE             R3                D3           U       M        C
# 221          NC             R2              D2.5           O       M        L
# 232          NU             R2                D3           O       T        R
# 233           N             R3              D3.5           O       T        R
# 234           N             R3                D4           O       T        C
# 257          NU             R2                D3           U       U        U
# 259          NU             R3                D3           U       T        C
# 260           N             R3                D3           I       M        L
# 262           N             R3                D2           G       T        C
# 263          AX             R4                D2           G       T        C
# 291           N             R3                D3           O       T        C
# 292           N             R4              D1.5           I       U        U
# 294           N              U                 U           U       U        U
# 295           N              U                 U           U       U        U
# 296           N              U                 U           U       U        U
# 297           N              U                 U           U       U        U
# 298           N              U                 U           U       U        U
# 299           N              U                 U           U       U        U
# 302           N             R4                D3           U       T        R
# 303           N              U                 U           U       U        U
# 305          NU             R2                D1           S       M        C
# 343          NU             R4              D2.5           O       T        C
# 386          NU             R1                D1           I       M        C
# 419          NU              U              D2.5           U       U        U
# 412          AX             R2              D1.5           S       T        R
# 413          AX             R2              D1.5           S       T        C
# 414          AX             R2              D1.5           S       T        L
# 415          AX             R2                D1           S       T        C
# 416          AX             R1                D1           S       M        C
# 424          NU             R3              D2.5           G       T        C
# 429          NU              U              D1.5           U       U        U
# 465          NU              U                D2           U       M        C
# 466           N             R3              D2.5           O       M        L
# 468          NC             R3                D3           O       T        C
# 471          AH             R4                D3           O       T        C
# 480          NU             R4                D2           O       T        C
# 483          NU              U              D1.5           I       U        U
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 39               0          0         N            0          0
# 73               0          0         N            0          0
# 89               0          0         N            0          0
# 143              0       1870         E         1333        537
# 221             38       1818         N         1318        500
# 232             40       2242         N         1230       1012
# 233             35       1924         N         1327        597
# 234             35       2212         N         1152       1060
# 257              0       1796         N         1257        539
# 259             40       1882         N         1294        588
# 260             40       2028        SE         1236        792
# 262             40       1588         N         1265        323
# 263             38       1353         N         1235        118
# 291             39       1697         N         1030        667
# 292              0          0         S         1353          0
# 294              0          0         N         1250          0
# 295              0          0         N         1265          0
# 296              0          0         N         1356          0
# 297              0          0         N         1364          0
# 298              0          0         N         1385          0
# 299              0          0         N         1364          0
# 302             38       1866         S         1322        544
# 303              0          0         N            0          0
# 305              0       1380         N         1347         33
# 343              0       1524         S         1280        244
# 386              0       1400        SE         1355         45
# 419              0          0         N            0          0
# 412              0       1527         N         1303        224
# 413              0       1527         S         1303        224
# 414              0       1527         S         1303        224
# 415              0       1386        SE         1347         39
# 416              0       1515         N         1370        145
# 424              0       1920         N         1340        580
# 429              0          0         N            0          0
# 465              0       1525         S         1310        215
# 466             40       1280         E         1220         60
# 468              0       2042         E         1310        732
# 471              0       1860        SE         1310        550
# 480              0       1646        SE         1297        349
# 483              0       1524        SE         1340        184
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 39                 0          0          0           0            BR
# 73                 0          0          0           0            BR
# 89                 0          0          0           0            BR
# 143               60        180         90         135            BR
# 221               60         90         60          75            BR
# 232              160        150        100         125            TK
# 233              360        120        120         120            MR
# 234              800        120        120         120            BR
# 257                0          0          0           0            MR
# 259               70         90         90          90            TR
# 260               45        120         90         105            BR
# 262                0          0          0           0             U
# 263               30         90         60          75             U
# 291              364        120        300         210            BR
# 292                0         30        100          65             U
# 294                0          0          0           0             U
# 295                0          0          0           0             U
# 296                0          0          0           0             U
# 297                0          0          0           0             U
# 298                0          0          0           0             U
# 299                0          0          0           0             U
# 302                0          0          0           0            BR
# 303                0          0          0           0             U
# 305               20         20         10          15             U
# 343                0          0          0           0            BR
# 386                0          0          0           0             U
# 419                0          0          0           0            BR
# 412               20         60         30          45             -
# 413               20         60         30          45             -
# 414               20         30         30          30             -
# 415               20         30         15          23             U
# 416               15         30         15          23             U
# 424                0          0          0           0             U
# 429                0          0          0           0             U
# 465                0          0          0           0            BR
# 466              100        150         30          90             U
# 468              500        300        100         200            BR
# 471              300        250        100         175            BR
# 480              100        130         25          78            BR
# 483                0          0          0           0             U
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 39                 -           U          U      True        30.0         0.2
# 73                 -           U          U      True        30.0         8.0
# 89                 -           U          U      True         0.0         0.0
# 143                -           U          D      True        20.0         0.5
# 221                -          2F          W      True         0.0         0.0
# 232                -           U          W     False         0.0         0.0
# 233                -           U          W      True        30.0        20.0
# 234                -           U          W     False         0.0         0.0
# 257                -           U          U      True        20.0         0.2
# 259                -           U          D      True        30.0         1.5
# 260                -           U          D      True       100.0         1.5
# 262               BP           U          W      True        10.0         0.8
# 263               BP          3F          D      True        30.0         1.0
# 291                -           -          D      True       120.0         2.0
# 292               BP           U          U      True        40.0         2.0
# 294               BP           U          U      True         0.0         0.0
# 295               BP           U          U      True         0.0         0.0
# 296                -           U          U      True         0.0         0.0
# 297                -           U          U      True         0.0         0.0
# 298                -           U          U      True         0.0         0.0
# 299                -           U          U      True         0.0         0.0
# 302                -           U          D      True       130.0         0.2
# 303               BP           U          D      True         0.0         0.0
# 305               BP           U          M      True         5.0         1.0
# 343                -           U          W      True         4.0         0.2
# 386               BP           U          W      True         7.0         0.7
# 419                -           U          U      True         0.0         0.0
# 412               BP           U          D      True        20.0         0.5
# 413               BP           U          D      True        20.0         1.0
# 414               BP           U          D      True        20.0         0.5
# 415               BP           U          D      True        20.0         1.0
# 416               BP           U          D      True        30.0         0.5
# 424                -           U          U      True         0.0         0.0
# 429               BP           U          U      True         0.0         0.0
# 465                -           -          D      True        10.0         1.5
# 466               BP           U          U      True        50.0         2.0
# 468                -          3F          D      True        80.0         2.0
# 471                -          3F          D      True       100.0         3.0
# 480                -           U          U      True        20.0         4.0
# 483               BP           U          W      True        15.0         2.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d  \
# avrid
# 39       False        0.0        0.0
# 73       False        0.0        0.0
# 89       False        0.0        0.0
# 143      False        0.0        0.0
# 221      False        0.0        0.0
# 232       True       20.0       20.0
# 233      False        0.0        0.0
# 234       True       30.0       20.0
# 257      False        0.0        0.0
# 259      False        0.0        0.0
# 260       True       20.0        0.1
# 262      False        0.0        0.0
# 263       True       10.0        0.2
# 291       True       30.0        0.1
# 292      False        0.0        0.0
# 294      False        0.0        0.0
# 295      False        0.0        0.0
# 296      False        0.0        0.0
# 297      False        0.0        0.0
# 298      False        0.0        0.0
# 299      False        0.0        0.0
# 302      False        0.0        0.0
# 303      False        0.0        0.0
# 305      False        0.0        0.0
# 343      False        0.0        0.0
# 386      False        0.0        0.0
# 419      False        0.0        0.0
# 412      False        0.0        0.0
# 413      False        0.0        0.0
# 414      False        0.0        0.0
# 415      False        0.0        0.0
# 416      False        0.0        0.0
# 424      False        0.0        0.0
# 429      False        0.0        0.0
# 465      False        0.0        0.0
# 466      False        0.0        0.0
# 468      False        0.0        0.0
# 471      False        0.0        0.0
# 480      False        0.0        0.0
# 483      False        0.0        0.0
#
#                                                avcomment edcr_user  \
# avrid
# 39     HS-N-R4-D3.5-O.  85% SZ.  This was a rain/snow...   Steiner
# 73     backfilled snowshed 30' height 100' linear - a...       NaN
# 89     8 foot crown, path filled and debris over the ...       NaN
# 143    Explosives triggered avalanche.  2006-02-25 mi...       NaN
# 221    Released as a SS at rain line about half way d...       Ted
# 232    SS-N-R2-D3-O.\nDebris terminated at Highway el...       Ted
# 233    SS-N-R3-D3+-O.  Avg. Aspect= 180\nTerminus con...       Ted
# 234    SS-N-R3-D4-O. Aspect= 240.\nRan full path pass...       Ted
# 257                         Terminated on Shed 10.7 roof       Ted
# 259    Terminated in runout below Shed 7.  Climbing l...       Ted
# 260    Natural SS avalanche in Path 1163 triggered na...       Ted
# 262    Wet, loose avalanche.  Covered Main 1- Inside ...       Ted
# 263    Triggered with Daisy Bell. Avalanche terminate...       Ted
# 291    1183 avalanche ran at approximately 2230 on 2/...       Ted
# 292    This avalanche released in steep rock band tha...       Ted
# 294    Time is approximate. Debris fully across main ...       Ted
# 295       Time is approximate. Debris across both mains.       Ted
# 296    Time is approximate. Debris fully across main ...       Ted
# 297    Time is approximate. Debris fully across main ...       Ted
# 298           Time is approximate. Debris across Main 1.       Ted
# 299       Time is approximate. Debris across both mains.       Ted
# 302    12/30/17: Infinity Path ran at approximately 0...       Ted
# 303    Dark hours avalanche. Debris deposited on both...       Ted
# 305    Did not cause slide fence damage or delay any ...       Ted
# 343    Likely ran PM 3/17. Two small fingers of debri...      Adam
# 386    Reported by a westbound train at 1145. Debris ...      Adam
# 419    Dark hours avalanche. Debris covered both Main...       NaN
# 412    Ignition 1 of 3. Debris terminated on grade an...       Ted
# 413    Ignition 2 of 3 in Jake's. Debris terminated o...       Ted
# 414    Ignition 3 of 3.  Terminated on grade. Debris ...       Ted
# 415      Debris terminated on the grade covering Main 1.       Ted
# 416      Debris terminated on the grade covering Main 1.       Ted
# 424                       Path filled, debris over shed.      Adam
# 429           Debris terminated at rail grade elevation.      Adam
# 465    Many details lacking for this avalanche. Possi...      Adam
# 466    Debris stopped at slide fence with no debris a...      Adam
# 468    Reported by track inspector shortly after 1100...      Adam
# 471    Triggered by one 5# charge. Debris ran over sh...      Adam
# 480    Slide fence indication and then reported by He...      Adam
# 483    Buried Main 1 and stopped an east-bound train....      Adam
#
#                 edcr_time        edcr_ip eded_user            eded_time  \
# avrid
# 39    2016-03-17 11:50:56             01       Ted  2020-06-29 11:14:49
# 73    2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:58:51
# 89    2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:36:19
# 143   2016-03-17 11:50:56            NaN       Ted  2020-06-29 10:42:33
# 221   2016-03-17 11:50:56   10.173.132.4       Ted  2020-06-29 11:44:57
# 232   2016-03-17 11:50:56   72.160.63.46       Ted  2020-06-29 12:25:56
# 233   2016-03-17 11:50:56   72.160.63.46       Ted  2020-06-29 12:33:15
# 234   2016-03-17 11:50:56   72.160.63.46       Ted  2020-06-29 11:52:37
# 257   2017-02-27 13:45:27   139.51.15.22       Ted  2020-06-29 10:16:11
# 259   2017-02-27 14:18:50   139.51.15.22       Ted  2020-06-29 10:14:50
# 260   2017-02-27 15:25:55   139.51.15.20       Ted  2020-06-29 13:13:18
# 262   2017-02-27 15:45:37   139.51.15.19       Ted  2020-06-29 10:28:52
# 263   2017-02-27 15:54:02   139.51.15.22       Ted  2020-06-29 09:58:06
# 291   2017-12-28 13:19:38   139.51.15.19       Ted  2020-06-29 10:33:44
# 292   2017-12-28 13:20:36   139.51.15.19       Ted  2020-06-29 13:31:05
# 294   2017-12-29 13:56:55   139.51.15.20       Ted  2020-06-29 10:19:56
# 295   2017-12-29 13:59:12   139.51.15.20       Ted  2020-06-29 10:20:35
# 296   2017-12-29 14:05:32   139.51.15.20       Ted  2020-06-29 10:21:19
# 297   2017-12-29 14:08:51   139.51.15.20       Ted  2020-06-29 10:22:27
# 298   2017-12-29 14:14:52   139.51.15.20       Ted  2020-06-29 10:23:41
# 299   2017-12-29 14:20:19   139.51.15.20       Ted  2020-06-29 10:24:12
# 302   2017-12-31 16:22:18   139.51.15.22       Ted  2020-06-29 13:08:44
# 303   2018-01-03 20:15:34   139.51.15.19       Ted  2020-06-29 10:13:01
# 305   2018-02-08 17:34:01   139.51.15.20       Ted  2020-06-29 12:55:59
# 343   2019-03-21 15:14:24   139.51.15.19      Adam  2020-05-31 23:23:59
# 386   2020-03-13 11:20:27   139.51.15.17      Adam  2020-05-31 23:26:20
# 419   2020-05-26 16:36:07  184.166.43.50       Ted  2020-06-29 10:25:11
# 412   2020-05-22 09:23:17    64.91.61.64       Ted  2020-06-29 10:09:34
# 413   2020-05-22 09:26:36    64.91.61.64       Ted  2020-06-29 13:19:21
# 414   2020-05-22 09:35:22    64.91.61.64       Ted  2020-06-29 13:18:48
# 415   2020-05-22 09:46:57    64.91.61.64       Ted  2020-06-29 13:31:53
# 416   2020-05-22 09:50:03    64.91.61.64       Ted  2020-06-29 10:12:12
# 424   2020-05-28 12:50:15   139.51.15.17       Ted  2020-06-29 10:34:37
# 429   2020-05-28 13:08:29   139.51.15.17       Ted  2020-06-29 10:59:56
# 465   2021-03-08 12:10:36     10.30.72.4      Adam  2021-03-08 12:13:55
# 466   2021-03-08 12:20:10     10.30.72.4      Adam  2021-03-08 12:23:07
# 468   2021-03-08 12:46:32     10.30.72.4      Adam  2021-03-08 12:47:03
# 471   2021-03-08 13:11:01     10.30.72.4       NaN  0000-00-00 00:00:00
# 480   2022-01-09 19:57:07     10.30.72.4       NaN  0000-00-00 00:00:00
# 483   2022-01-14 20:00:22     10.30.72.4      Adam  2022-03-08 00:59:39
#
#              eded_ip
# avrid
# 39       64.91.61.64
# 73       64.91.61.64
# 89       64.91.61.64
# 143      64.91.61.64
# 221      64.91.61.64
# 232      64.91.61.64
# 233      64.91.61.64
# 234      64.91.61.64
# 257      64.91.61.64
# 259      64.91.61.64
# 260      64.91.61.64
# 262      64.91.61.64
# 263      64.91.61.64
# 291      64.91.61.64
# 292      64.91.61.64
# 294      64.91.61.64
# 295      64.91.61.64
# 296      64.91.61.64
# 297      64.91.61.64
# 298      64.91.61.64
# 299      64.91.61.64
# 302      64.91.61.64
# 303      64.91.61.64
# 305      64.91.61.64
# 343    184.166.43.50
# 386    184.166.43.50
# 419      64.91.61.64
# 412      64.91.61.64
# 413      64.91.61.64
# 414      64.91.61.64
# 415      64.91.61.64
# 416      64.91.61.64
# 424      64.91.61.64
# 429      64.91.61.64
# 465       10.30.72.4
# 466       10.30.72.4
# 468       10.30.72.4
# 471              NaN
# 480              NaN
# 483    184.166.43.50

# %%
grouprailhwy = both.groupby('deb_rail').deb_rail.count()
grouprailhwy
# Out:
# deb_rail
# False     2
# True     38
# Name: deb_rail, dtype: int64
