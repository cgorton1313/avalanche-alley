# %% [markdown]
# # Data Visualization

# %%
from IPython.display import Image

# %% [markdown]
# ## The path that has the most avalanches is PATH1163

# %%
Image("../Visualizations- A/paths_avalanches.png")

# %% [markdown]
# ## Another way of showing PATH1163 has the most avalanches

# %%
Image("../Visualizations- A/allpaths.png")

# %% [markdown]
# ## This shows which paths hit the rail or didn't hit the rail. The blue means it didn't hit the rail.

# %%
Image("../Visualizations- A/true_false_rail.png")

# %% [markdown]
# ## This shows which paths hit the highway or didn't hit the highway. The blue means it didn't hit the highway.

# %%
Image("../Visualizations- A/true_false_hwy.png")

# %% [markdown]
# ## This combines the last two graphs to show which ones hit only the rail and/or highway. Blue = hit the rail. Orange = hit the Highway. Green = hit both

# %%
Image("../Visualizations- A/hwy_rail.png")

# %% [markdown]
# ## This graph shows the paths amount of avalanches over the years

# %%
Image("../Visualizations- A/pathduringyear.png")

# %% [markdown]
# ## This shows the paths with the biggest crownwidth and whether or not they hit the rail. Blue means they didn't hit the rail.

# %%
Image("../Visualizations- A/newcrownbigtrail.png")

# %% [markdown]
# ## This shows the crown width for all the trails and whether or not they hit the rail. Blue means they did not hit the rail.

# %%
Image("../Visualizations- A/all_crown.png")

# %% [markdown]
# ## This graph shows the average snowdepth over all the years of data

# %%
Image("../Visualizations- A/averagesnowdepth.png")

# %% [markdown]
# ## This graph shows the snow depth for the year of 2022

# %%
Image("../Visualizations- A/2022snowdepth.png")

# %% [markdown]
# ## This graph shows the snow depth throughout the years of 2019, 2020, 2021, and 2022. Years before 2019 are not included because there was no data available for those years.

# %%
Image("../Visualizations- A/seperstesnowdepth.png")

# %% [markdown]
# ## This graph combines the graph above

# %%
Image("../Visualizations- A/alltogethersnowdepth.png")

# %% [markdown]
# ## This graph shows the average snowdepth for the month of February

# %%
Image("../Visualizations- A/weatherfebruary.png")

# %% [markdown]
# ## This graph shows the paths that hit or didn't hit the rail for the month of February. Blue means it didn't hit the rail.

# %%
Image("../Visualizations- A/pathsfebruary.png")
