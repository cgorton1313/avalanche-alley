# %%
import pandas as pd

rads = pd.read_pickle('data-prep/pkl/rads.pkl')
rads.Date = pd.to_datetime(rads.Date)

avy = pd.read_pickle('data-prep/pkl/avy_obs.pkl')
avy['Date'] = avy.avobsdate

# %%
rads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 794 entries, 0 to 793
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    794 non-null    datetime64[ns]
#  1   Time    794 non-null    object
#  2   Score   701 non-null    float64
#  3   Level   794 non-null    int64
# dtypes: datetime64[ns](1), float64(1), int64(1), object(1)
# memory usage: 24.9+ KB

# %%
avy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 1 to 508
# Data columns (total 39 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avpathid           491 non-null    object
#  1   avobsdate          491 non-null    datetime64[ns]
#  2   avobstime          491 non-null    object
#  3   avobserverid       491 non-null    object
#  4   avtype             485 non-null    object
#  5   avtriggertyp       455 non-null    float64
#  6   avtrigger          446 non-null    object
#  7   avrelativesize     474 non-null    object
#  8   avdestructivesize  441 non-null    object
#  9   avinterface        431 non-null    object
#  10  sz_vert            470 non-null    object
#  11  sz_horiz           453 non-null    object
#  12  sz_avgslope        491 non-null    int64
#  13  sz_elev_m          491 non-null    int64
#  14  sz_aspect          105 non-null    object
#  15  term_elev_m        491 non-null    int64
#  16  av_vert_m          491 non-null    int64
#  17  crown_width_m      491 non-null    int64
#  18  ch_max_cm          491 non-null    int64
#  19  ch_min_cm          491 non-null    int64
#  20  ch_diff_cm         491 non-null    int64
#  21  term_longpath      461 non-null    object
#  22  term_shortPath     326 non-null    object
#  23  term_detail        307 non-null    object
#  24  term_moist         378 non-null    object
#  25  deb_rail           491 non-null    bool
#  26  deb_rail_w         491 non-null    float64
#  27  deb_rail_d         491 non-null    float64
#  28  deb_hwy            491 non-null    bool
#  29  deb_hwy_w          491 non-null    float64
#  30  deb_hwy_d          491 non-null    float64
#  31  avcomment          362 non-null    object
#  32  edcr_user          364 non-null    object
#  33  edcr_time          491 non-null    datetime64[ns]
#  34  edcr_ip            393 non-null    object
#  35  eded_user          197 non-null    object
#  36  eded_time          491 non-null    object
#  37  eded_ip            198 non-null    object
#  38  Date               491 non-null    datetime64[ns]
# dtypes: bool(2), datetime64[ns](3), float64(5), int64(8), object(21)
# memory usage: 146.7+ KB

# %%
radsavy = pd.merge(rads, avy, on=["Date"])
radsavy
# Out:
#           Date      Time  Score  Level  avpathid  avobsdate avobstime  \
# 0   2007-01-19  00:00:00    NaN      2    SHED11 2007-01-19  13:20:00
# 1   2007-02-07  00:00:00    NaN      1    SHED11 2007-02-07  09:30:00
# 2   2007-02-07  00:00:00    NaN      1      JAVA 2007-02-07  09:45:00
# 3   2007-02-16  00:00:00    NaN      1  PATH1163 2007-02-16  10:10:00
# 4   2007-02-16  00:00:00    NaN      1     JAKES 2007-02-16  10:10:00
# ..         ...       ...    ...    ...       ...        ...       ...
# 480 2022-03-01  00:00:00   80.0      3   SHED07W 2022-03-01  05:04:00
# 481 2022-03-02  00:00:00   70.0      2  INFINITY 2022-03-02  11:35:00
# 482 2022-03-23  00:00:00   41.0      1   AP1163H 2022-03-23  13:30:00
# 483 2022-03-23  00:00:00   41.0      1    SHED10 2022-03-23  13:30:00
# 484 2022-03-23  00:00:00   41.0      1   MCAMSER 2022-03-23  18:00:00
#
#     avobserverid avtype  avtriggertyp  ... deb_hwy deb_hwy_w deb_hwy_d  \
# 0       stein_01      U           NaN  ...   False       0.0       0.0
# 1       stein_01     GS           5.0  ...   False       0.0       0.0
# 2       clark_01     SS           5.0  ...   False       0.0       0.0
# 3       stein_01      L           5.0  ...   False       0.0       0.0
# 4       stein_01     SS           5.0  ...   False       0.0       0.0
# ..           ...    ...           ...  ...     ...       ...       ...
# 480     clark_01     SS           5.0  ...   False       0.0       0.0
# 481     clark_01     WL           5.0  ...   False       0.0       0.0
# 482     clark_01     WL           5.0  ...   False       0.0       0.0
# 483     clark_01     WL           5.0  ...   False       0.0       0.0
# 484     clark_01     HS           5.0  ...   False       0.0       0.0
#
#                                              avcomment edcr_user  \
# 0                                                  NaN       NaN
# 1    Debris terminated in bottom of run out, but st...       NaN
# 2                 Located on the top of Java Mountain.      Adam
# 3      Debris ran 1/2 path terminating above the rail.       NaN
# 4      Debris ran 1/2 path terminating above the rail.       NaN
# ..                                                 ...       ...
# 480  Slab not observed until March 17th during a sk...      Adam
# 481  One of the last avalanches observed during the...      Adam
# 482                                                NaN      Adam
# 483                          Obs on Mar. 24th from Hwy      Adam
# 484  Obs on Mar. 24th from Hwy. Could not see runou...      Adam
#
#               edcr_time       edcr_ip  eded_user            eded_time  \
# 0   2016-03-17 11:50:56           NaN        NaN  0000-00-00 00:00:00
# 1   2016-03-17 11:50:56           NaN       Adam  2020-05-28 14:26:45
# 2   2020-05-28 14:31:17  139.51.15.17        NaN  0000-00-00 00:00:00
# 3   2016-03-17 11:50:56           NaN       Adam  2020-05-28 14:27:39
# 4   2016-03-17 11:50:56           NaN       Adam  2020-05-28 14:28:15
# ..                  ...           ...        ...                  ...
# 480 2022-03-17 21:17:04    10.30.72.4        NaN  0000-00-00 00:00:00
# 481 2022-03-15 13:38:53    10.30.72.4        NaN  0000-00-00 00:00:00
# 482 2022-03-23 21:32:42    10.30.72.4        NaN  0000-00-00 00:00:00
# 483 2022-03-28 16:30:35    10.30.72.4        NaN  0000-00-00 00:00:00
# 484 2022-03-28 16:34:43    10.30.72.4        NaN  0000-00-00 00:00:00
#
#           eded_ip
# 0             NaN
# 1    139.51.15.17
# 2             NaN
# 3    139.51.15.17
# 4    139.51.15.17
# ..            ...
# 480           NaN
# 481           NaN
# 482           NaN
# 483           NaN
# 484           NaN
#
# [485 rows x 42 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
radsavy2012 = radsavy.loc[radsavy.Date.dt.year >= 2012]
radsavy2012
# Out:
#           Date      Time  Score  Level    avpathid  avobsdate avobstime  \
# 100 2012-01-19  00:00:00   55.0      2      SHED06 2012-01-19  11:30:00
# 101 2012-02-21  00:00:00   54.0      2  TestSlope1 2012-02-21  11:00:00
# 102 2012-02-21  00:00:00   54.0      2     SHED07W 2012-02-21  10:00:00
# 103 2012-02-21  00:00:00   54.0      2     SHED07E 2012-02-21  10:00:00
# 104 2012-02-21  00:00:00   54.0      2      SHED05 2012-02-21  01:00:00
# ..         ...       ...    ...    ...         ...        ...       ...
# 480 2022-03-01  00:00:00   80.0      3     SHED07W 2022-03-01  05:04:00
# 481 2022-03-02  00:00:00   70.0      2    INFINITY 2022-03-02  11:35:00
# 482 2022-03-23  00:00:00   41.0      1     AP1163H 2022-03-23  13:30:00
# 483 2022-03-23  00:00:00   41.0      1      SHED10 2022-03-23  13:30:00
# 484 2022-03-23  00:00:00   41.0      1     MCAMSER 2022-03-23  18:00:00
#
#     avobserverid avtype  avtriggertyp  ... deb_hwy deb_hwy_w deb_hwy_d  \
# 100     dunda_01     SS           5.0  ...   False       0.0       0.0
# 101     stein_01     HS           5.0  ...   False       0.0       0.0
# 102     stein_01     SS           5.0  ...   False       0.0       0.0
# 103     stein_01     SS           5.0  ...   False       0.0       0.0
# 104     stein_01     SS           5.0  ...   False       0.0       0.0
# ..           ...    ...           ...  ...     ...       ...       ...
# 480     clark_01     SS           5.0  ...   False       0.0       0.0
# 481     clark_01     WL           5.0  ...   False       0.0       0.0
# 482     clark_01     WL           5.0  ...   False       0.0       0.0
# 483     clark_01     WL           5.0  ...   False       0.0       0.0
# 484     clark_01     HS           5.0  ...   False       0.0       0.0
#
#                                              avcomment edcr_user  \
# 100  Widespread low elevation small magnitude slab ...        ed
# 101  HS-N-R4D2-O.  Crown Width= 120m Crown depth 0....        ed
# 102  Isolated SS located on S aspect of path- Looke...        ed
# 103      Ran in main Shed 7 path to 150m above Shed 7.        ed
# 104  Triggered in isolated rock outcrop- Looker's R...        ed
# ..                                                 ...       ...
# 480  Slab not observed until March 17th during a sk...      Adam
# 481  One of the last avalanches observed during the...      Adam
# 482                                                NaN      Adam
# 483                          Obs on Mar. 24th from Hwy      Adam
# 484  Obs on Mar. 24th from Hwy. Could not see runou...      Adam
#
#               edcr_time       edcr_ip  eded_user            eded_time  eded_ip
# 100 2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00      NaN
# 101 2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00      NaN
# 102 2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00      NaN
# 103 2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00      NaN
# 104 2016-03-17 11:50:56  10.173.132.2         ed  2019-01-02 00:00:00   server
# ..                  ...           ...        ...                  ...      ...
# 480 2022-03-17 21:17:04    10.30.72.4        NaN  0000-00-00 00:00:00      NaN
# 481 2022-03-15 13:38:53    10.30.72.4        NaN  0000-00-00 00:00:00      NaN
# 482 2022-03-23 21:32:42    10.30.72.4        NaN  0000-00-00 00:00:00      NaN
# 483 2022-03-28 16:30:35    10.30.72.4        NaN  0000-00-00 00:00:00      NaN
# 484 2022-03-28 16:34:43    10.30.72.4        NaN  0000-00-00 00:00:00      NaN
#
# [385 rows x 42 columns]

# %%
sns.countplot(data=radsavy, x='Date', color='blue')
plt.show()
sns.scatterplot(data=radsavy, x='Date', y='Level', color='red')
plt.show()
