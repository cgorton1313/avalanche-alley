# %%
import pandas as pd

avy = pd.read_pickle("./data-prep/pkl/avy_obs.pkl")
wx = pd.read_pickle("./data-prep/pkl/all_wx.pkl")

# %%
avy['time'] = pd.to_datetime(avy['avobstime'], format='%H:%M:%S').dt.time
avy['dt'] = [date.replace(hour=time.hour, minute=time.minute) for date, time in zip(avy.avobsdate, avy.time)]
avy
# Out:
#        avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1        SHED10 2012-03-26  12:45:00     stein_01     WS           5.0
# 2      PATH1163 2012-03-16  08:30:00     stein_01      U           5.0
# 3         CURLY 2012-03-16  08:34:00     stein_01      U           5.0
# 4        SHED10 2012-03-10  14:50:00     stein_01     WL           5.0
# 5      INFINITY 2012-03-10  14:54:00     stein_01      L           5.0
# ...         ...        ...       ...          ...    ...           ...
# 504     SHED07W 2022-03-01  05:04:00     clark_01     SS           5.0
# 505     AP1163H 2022-03-23  13:30:00     clark_01     WL           5.0
# 506      SHED10 2022-03-23  13:30:00     clark_01     WL           5.0
# 507     MCAMSER 2022-03-23  18:00:00     clark_01     HS           5.0
# 508    PATH1163 2022-03-27  14:35:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface  ... deb_hwy_d  \
# avrid                                                         ...
# 1            NL             R1              D1.5           O  ...       0.0
# 2            NU              U                D2           U  ...       0.0
# 3            NU              U                D1           U  ...       0.0
# 4           NaN             R2                D1           I  ...       0.0
# 5             N             R2                D1           I  ...       0.0
# ...         ...            ...               ...         ...  ...       ...
# 504          NC             R2                D2           I  ...       0.0
# 505          NU             R1              D1.5           O  ...       0.0
# 506           N             R2                D2           O  ...       0.0
# 507          NC             R3                D3           O  ...       0.0
# 508           N             R1                D2           O  ...       0.0
#
#                                                avcomment  edcr_user  \
# avrid
# 1      Wet slab released on SE aspect @ 5400 feet (16...         ed
# 2      Wet debris ran 2/3 path in main path to 4700 f...         ed
# 3      Terminus at canyon floor elevation.\r\n\r\nDeb...         ed
# 4                                                   D1.5         ed
# 5                                        D1.5- 1/2 Path.         ed
# ...                                                  ...        ...
# 504    Slab not observed until March 17th during a sk...       Adam
# 505                                                  NaN       Adam
# 506                            Obs on Mar. 24th from Hwy       Adam
# 507    Obs on Mar. 24th from Hwy. Could not see runou...       Adam
# 508                          Obs. on Mar. 28th from Hwy.       Adam
#
#                 edcr_time       edcr_ip  eded_user            eded_time  \
# avrid
# 1     2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00
# 2     2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00
# 3     2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00
# 4     2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00
# 5     2016-03-17 11:50:56  10.173.132.2        NaN  0000-00-00 00:00:00
# ...                   ...           ...        ...                  ...
# 504   2022-03-17 21:17:04    10.30.72.4        NaN  0000-00-00 00:00:00
# 505   2022-03-23 21:32:42    10.30.72.4        NaN  0000-00-00 00:00:00
# 506   2022-03-28 16:30:35    10.30.72.4        NaN  0000-00-00 00:00:00
# 507   2022-03-28 16:34:43    10.30.72.4        NaN  0000-00-00 00:00:00
# 508   2022-03-28 16:37:03    10.30.72.4        NaN  0000-00-00 00:00:00
#
#        eded_ip      time                  dt
# avrid
# 1          NaN  12:45:00 2012-03-26 12:45:00
# 2          NaN  08:30:00 2012-03-16 08:30:00
# 3          NaN  08:34:00 2012-03-16 08:34:00
# 4          NaN  14:50:00 2012-03-10 14:50:00
# 5          NaN  14:54:00 2012-03-10 14:54:00
# ...        ...       ...                 ...
# 504        NaN  05:04:00 2022-03-01 05:04:00
# 505        NaN  13:30:00 2022-03-23 13:30:00
# 506        NaN  13:30:00 2022-03-23 13:30:00
# 507        NaN  18:00:00 2022-03-23 18:00:00
# 508        NaN  14:35:00 2022-03-27 14:35:00
#
# [491 rows x 40 columns]

# %%
sh11_wx = wx.loc[wx.site == 'S11MT']
sh11_wx.head(4)
# Out:
#                        dt  temp  dew_pt    rH  heat_idx  wind_chill wind_dir  \
# 26167 2022-12-23 04:00:00 -10.0   -15.0  78.0       NaN         NaN        W
# 26168 2022-12-23 03:00:00 -11.0   -16.0  78.0       NaN         NaN       SW
# 26169 2022-12-23 02:00:00 -12.0   -17.0  78.0       NaN         NaN      WSW
# 26170 2022-12-23 01:00:00 -13.0   -18.0  78.0       NaN         NaN       SW
#
#       wind_spd  hr_precip  snow_depth  ...  snowfall_6hr  snowfall_24hr  \
# 26167      2G4        NaN        54.0  ...           0.0            0.0
# 26168      2G5        NaN        54.1  ...           0.0            0.0
# 26169      2G5        NaN        54.4  ...           0.0            0.0
# 26170      3G7        NaN        54.5  ...           0.0            0.0
#
#         site        file_name  year sea_lvl_press  sta_press  \
# 26167  S11MT  S11MT-2022.html  2022           NaN        NaN
# 26168  S11MT  S11MT-2022.html  2022           NaN        NaN
# 26169  S11MT  S11MT-2022.html  2022           NaN        NaN
# 26170  S11MT  S11MT-2022.html  2022           NaN        NaN
#
#        altimeter_setting  solar_radiation  pct_possible
# 26167                NaN              NaN           NaN
# 26168                NaN              NaN           NaN
# 26169                NaN              NaN           NaN
# 26170                NaN              NaN           NaN
#
# [4 rows x 21 columns]

# %%
def get_wx_record(avrid, avy_dt, wx):
    prev_wx_obs = wx.loc[wx.dt <= avy_dt].sort_values(by=['dt'], ascending=False).head(1)
    if len(prev_wx_obs) > 0: # if we have a wx obs prior to the avy
        time_diff_hrs = (avy_dt - prev_wx_obs.dt).astype('timedelta64[h]')
        if time_diff_hrs.iloc[0] < 72:
            return prev_wx_obs
        
temp_df = pd.DataFrame()

for avrid, dt in zip(avy.index, avy.dt):
    wx_record = get_wx_record(avrid, dt, sh11_wx)
    if wx_record is not None:
        wx_record['avrid'] = avrid
        temp_df = pd.concat([temp_df, wx_record])

temp_df.set_index('avrid', inplace=True)
temp_df.rename(columns={'dt': 'wx_dt'}, inplace=True)
temp_df
# Out:
#                     wx_dt  temp  dew_pt    rH  heat_idx  wind_chill wind_dir  \
# avrid
# 368   2019-12-13 11:00:00  23.0    21.0  92.0       NaN         NaN       SW
# 369   2019-12-20 14:00:00  32.0    29.0  88.0       NaN        23.0       SW
# 370   2019-12-20 14:00:00  32.0    29.0  88.0       NaN        23.0       SW
# 371   2020-01-01 11:00:00  27.0    26.0  95.0       NaN         NaN       SW
# 372   2020-01-01 13:00:00  28.0    27.0  95.0       NaN         NaN       SW
# ...                   ...   ...     ...   ...       ...         ...      ...
# 504   2022-03-01 05:00:00  31.0    30.0  96.0       NaN         NaN       NW
# 505   2022-03-23 13:00:00  38.0    31.0  77.0       NaN         NaN      WNW
# 506   2022-03-23 13:00:00  38.0    31.0  77.0       NaN         NaN      WNW
# 507   2022-03-23 18:00:00  48.0    32.0  53.0       NaN         NaN       SW
# 508   2022-03-27 14:00:00  48.0    26.0  43.0       NaN         NaN        W
#
#       wind_spd  hr_precip  snow_depth  ...  snowfall_6hr  snowfall_24hr  \
# avrid                                  ...
# 368       5G17        NaN        29.7  ...           1.9            1.6
# 369      11G31        NaN        31.5  ...           1.3            4.1
# 370      11G31        NaN        31.5  ...           1.3            4.1
# 371       4G13        NaN        32.0  ...           0.0            NaN
# 372       4G13        NaN        33.3  ...           0.4            NaN
# ...        ...        ...         ...  ...           ...            ...
# 504       4G15        NaN        79.8  ...           0.2           11.1
# 505       3G11        NaN        85.3  ...           0.0            0.0
# 506       3G11        NaN        85.3  ...           0.0            0.0
# 507       4G12        NaN        83.4  ...           0.0            0.0
# 508       3G10        NaN        77.0  ...           0.0            0.0
#
#         site        file_name  year sea_lvl_press  sta_press  \
# avrid
# 368    S11MT  S11MT-2019.html  2019           NaN        NaN
# 369    S11MT  S11MT-2019.html  2019           NaN        NaN
# 370    S11MT  S11MT-2019.html  2019           NaN        NaN
# 371    S11MT  S11MT-2020.html  2020           NaN        NaN
# 372    S11MT  S11MT-2020.html  2020           NaN        NaN
# ...      ...              ...   ...           ...        ...
# 504    S11MT  S11MT-2022.html  2022           NaN        NaN
# 505    S11MT  S11MT-2022.html  2022           NaN        NaN
# 506    S11MT  S11MT-2022.html  2022           NaN        NaN
# 507    S11MT  S11MT-2022.html  2022           NaN        NaN
# 508    S11MT  S11MT-2022.html  2022           NaN        NaN
#
#        altimeter_setting  solar_radiation  pct_possible
# avrid
# 368                  NaN              NaN           NaN
# 369                  NaN              NaN           NaN
# 370                  NaN              NaN           NaN
# 371                  NaN              NaN           NaN
# 372                  NaN              NaN           NaN
# ...                  ...              ...           ...
# 504                  NaN              NaN           NaN
# 505                  NaN              NaN           NaN
# 506                  NaN              NaN           NaN
# 507                  NaN              NaN           NaN
# 508                  NaN              NaN           NaN
#
# [89 rows x 21 columns]

# %%
avy_obs_with_wx = pd.concat([avy, temp_df], axis='columns')

pd.set_option("display.max_columns", None)

avy_obs_with_wx
# Out:
#        avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1        SHED10 2012-03-26  12:45:00     stein_01     WS           5.0
# 2      PATH1163 2012-03-16  08:30:00     stein_01      U           5.0
# 3         CURLY 2012-03-16  08:34:00     stein_01      U           5.0
# 4        SHED10 2012-03-10  14:50:00     stein_01     WL           5.0
# 5      INFINITY 2012-03-10  14:54:00     stein_01      L           5.0
# ...         ...        ...       ...          ...    ...           ...
# 504     SHED07W 2022-03-01  05:04:00     clark_01     SS           5.0
# 505     AP1163H 2022-03-23  13:30:00     clark_01     WL           5.0
# 506      SHED10 2022-03-23  13:30:00     clark_01     WL           5.0
# 507     MCAMSER 2022-03-23  18:00:00     clark_01     HS           5.0
# 508    PATH1163 2022-03-27  14:35:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 1            NL             R1              D1.5           O       B        R
# 2            NU              U                D2           U       U        U
# 3            NU              U                D1           U       U        U
# 4           NaN             R2                D1           I       M        R
# 5             N             R2                D1           I       T        C
# ...         ...            ...               ...         ...     ...      ...
# 504          NC             R2                D2           I       T        L
# 505          NU             R1              D1.5           O       T        U
# 506           N             R2                D2           O       T        C
# 507          NC             R3                D3           O       T        C
# 508           N             R1                D2           O       T        L
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 1                0          0       NaN            0          0
# 2                0          0       NaN            0          0
# 3                0          0       NaN            0          0
# 4                0          0       NaN            0          0
# 5                0          0       NaN            0          0
# ...            ...        ...       ...          ...        ...
# 504             38       2015         E         1760        255
# 505              0       1830        SW         1460        370
# 506             40       2075        SE         1646        429
# 507             40       2195        SE         1790        405
# 508             40       2135        SE         1400        735
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 1                  0          0          0           0            TK
# 2                  0          0          0           0            TK
# 3                  0          0          0           0            TR
# 4                  0          0          0           0            TK
# 5                  0          0          0           0            TK
# ...              ...        ...        ...         ...           ...
# 504                0          0          0           0            TK
# 505                0          0          0           0            TR
# 506                0          0          0           0            TK
# 507              245        150         40          95            MR
# 508                0          0          0           0            MR
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 1                NaN         NaN        NaN     False         0.0         0.0
# 2                NaN         NaN        NaN     False         0.0         0.0
# 3                NaN         NaN        NaN     False         0.0         0.0
# 4                NaN         NaN        NaN     False         0.0         0.0
# 5                NaN         NaN        NaN     False         0.0         0.0
# ...              ...         ...        ...       ...         ...         ...
# 504                -           U          U     False         0.0         0.0
# 505                -           U          W     False         0.0         0.0
# 506                -           U          W     False         0.0         0.0
# 507                -           U          U     False         0.0         0.0
# 508                -           U          W     False         0.0         0.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d  \
# avrid
# 1        False        0.0        0.0
# 2        False        0.0        0.0
# 3        False        0.0        0.0
# 4        False        0.0        0.0
# 5        False        0.0        0.0
# ...        ...        ...        ...
# 504      False        0.0        0.0
# 505      False        0.0        0.0
# 506      False        0.0        0.0
# 507      False        0.0        0.0
# 508      False        0.0        0.0
#
#                                                avcomment edcr_user  \
# avrid
# 1      Wet slab released on SE aspect @ 5400 feet (16...        ed
# 2      Wet debris ran 2/3 path in main path to 4700 f...        ed
# 3      Terminus at canyon floor elevation.\r\n\r\nDeb...        ed
# 4                                                   D1.5        ed
# 5                                        D1.5- 1/2 Path.        ed
# ...                                                  ...       ...
# 504    Slab not observed until March 17th during a sk...      Adam
# 505                                                  NaN      Adam
# 506                            Obs on Mar. 24th from Hwy      Adam
# 507    Obs on Mar. 24th from Hwy. Could not see runou...      Adam
# 508                          Obs. on Mar. 28th from Hwy.      Adam
#
#                 edcr_time       edcr_ip eded_user            eded_time  \
# avrid
# 1     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00
# 2     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00
# 3     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00
# 4     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00
# 5     2016-03-17 11:50:56  10.173.132.2       NaN  0000-00-00 00:00:00
# ...                   ...           ...       ...                  ...
# 504   2022-03-17 21:17:04    10.30.72.4       NaN  0000-00-00 00:00:00
# 505   2022-03-23 21:32:42    10.30.72.4       NaN  0000-00-00 00:00:00
# 506   2022-03-28 16:30:35    10.30.72.4       NaN  0000-00-00 00:00:00
# 507   2022-03-28 16:34:43    10.30.72.4       NaN  0000-00-00 00:00:00
# 508   2022-03-28 16:37:03    10.30.72.4       NaN  0000-00-00 00:00:00
#
#       eded_ip      time                  dt               wx_dt  temp  dew_pt  \
# avrid
# 1         NaN  12:45:00 2012-03-26 12:45:00                 NaT   NaN     NaN
# 2         NaN  08:30:00 2012-03-16 08:30:00                 NaT   NaN     NaN
# 3         NaN  08:34:00 2012-03-16 08:34:00                 NaT   NaN     NaN
# 4         NaN  14:50:00 2012-03-10 14:50:00                 NaT   NaN     NaN
# 5         NaN  14:54:00 2012-03-10 14:54:00                 NaT   NaN     NaN
# ...       ...       ...                 ...                 ...   ...     ...
# 504       NaN  05:04:00 2022-03-01 05:04:00 2022-03-01 05:00:00  31.0    30.0
# 505       NaN  13:30:00 2022-03-23 13:30:00 2022-03-23 13:00:00  38.0    31.0
# 506       NaN  13:30:00 2022-03-23 13:30:00 2022-03-23 13:00:00  38.0    31.0
# 507       NaN  18:00:00 2022-03-23 18:00:00 2022-03-23 18:00:00  48.0    32.0
# 508       NaN  14:35:00 2022-03-27 14:35:00 2022-03-27 14:00:00  48.0    26.0
#
#          rH  heat_idx  wind_chill wind_dir wind_spd  hr_precip  snow_depth  \
# avrid
# 1       NaN       NaN         NaN      NaN      NaN        NaN         NaN
# 2       NaN       NaN         NaN      NaN      NaN        NaN         NaN
# 3       NaN       NaN         NaN      NaN      NaN        NaN         NaN
# 4       NaN       NaN         NaN      NaN      NaN        NaN         NaN
# 5       NaN       NaN         NaN      NaN      NaN        NaN         NaN
# ...     ...       ...         ...      ...      ...        ...         ...
# 504    96.0       NaN         NaN       NW     4G15        NaN        79.8
# 505    77.0       NaN         NaN      WNW     3G11        NaN        85.3
# 506    77.0       NaN         NaN      WNW     3G11        NaN        85.3
# 507    53.0       NaN         NaN       SW     4G12        NaN        83.4
# 508    43.0       NaN         NaN        W     3G10        NaN        77.0
#
#        snowfall_3hr  snowfall_6hr  snowfall_24hr   site        file_name  \
# avrid
# 1               NaN           NaN            NaN    NaN              NaN
# 2               NaN           NaN            NaN    NaN              NaN
# 3               NaN           NaN            NaN    NaN              NaN
# 4               NaN           NaN            NaN    NaN              NaN
# 5               NaN           NaN            NaN    NaN              NaN
# ...             ...           ...            ...    ...              ...
# 504             0.0           0.2           11.1  S11MT  S11MT-2022.html
# 505             0.0           0.0            0.0  S11MT  S11MT-2022.html
# 506             0.0           0.0            0.0  S11MT  S11MT-2022.html
# 507             0.0           0.0            0.0  S11MT  S11MT-2022.html
# 508             0.0           0.0            0.0  S11MT  S11MT-2022.html
#
#        year  sea_lvl_press  sta_press  altimeter_setting  solar_radiation  \
# avrid
# 1       NaN            NaN        NaN                NaN              NaN
# 2       NaN            NaN        NaN                NaN              NaN
# 3       NaN            NaN        NaN                NaN              NaN
# 4       NaN            NaN        NaN                NaN              NaN
# 5       NaN            NaN        NaN                NaN              NaN
# ...     ...            ...        ...                ...              ...
# 504    2022            NaN        NaN                NaN              NaN
# 505    2022            NaN        NaN                NaN              NaN
# 506    2022            NaN        NaN                NaN              NaN
# 507    2022            NaN        NaN                NaN              NaN
# 508    2022            NaN        NaN                NaN              NaN
#
#       pct_possible
# avrid
# 1              NaN
# 2              NaN
# 3              NaN
# 4              NaN
# 5              NaN
# ...            ...
# 504            NaN
# 505            NaN
# 506            NaN
# 507            NaN
# 508            NaN
#
# [491 rows x 61 columns]

# %%
cols = ['avpathid', 'avobsdate', 'avobstime', 'avtype',
       'avtriggertyp', 'avtrigger', 'avrelativesize', 'avdestructivesize',
       'avinterface', 'sz_vert', 'sz_horiz', 'sz_avgslope', 'sz_elev_m',
       'sz_aspect', 'term_elev_m', 'av_vert_m', 'crown_width_m', 'ch_max_cm',
       'ch_min_cm', 'ch_diff_cm', 'term_longpath', 'term_shortPath',
       'term_detail', 'term_moist', 'deb_rail', 'deb_rail_w', 'deb_rail_d',
       'deb_hwy', 'deb_hwy_w', 'deb_hwy_d', 'time',
       'dt', 'wx_dt', 'temp', 'dew_pt', 'rH', 'heat_idx', 'wind_chill',
       'wind_dir', 'wind_spd', 'hr_precip', 'snow_depth', 'snowfall_3hr',
       'snowfall_6hr', 'snowfall_24hr', 'site', 'year',
       'sea_lvl_press', 'sta_press', 'altimeter_setting', 'solar_radiation',
       'pct_possible']


avywx = avy_obs_with_wx.loc[:, cols]

avywx
# Out:
#        avpathid  avobsdate avobstime avtype  avtriggertyp avtrigger  \
# avrid
# 1        SHED10 2012-03-26  12:45:00     WS           5.0        NL
# 2      PATH1163 2012-03-16  08:30:00      U           5.0        NU
# 3         CURLY 2012-03-16  08:34:00      U           5.0        NU
# 4        SHED10 2012-03-10  14:50:00     WL           5.0       NaN
# 5      INFINITY 2012-03-10  14:54:00      L           5.0         N
# ...         ...        ...       ...    ...           ...       ...
# 504     SHED07W 2022-03-01  05:04:00     SS           5.0        NC
# 505     AP1163H 2022-03-23  13:30:00     WL           5.0        NU
# 506      SHED10 2022-03-23  13:30:00     WL           5.0         N
# 507     MCAMSER 2022-03-23  18:00:00     HS           5.0        NC
# 508    PATH1163 2022-03-27  14:35:00     WL           5.0         N
#
#       avrelativesize avdestructivesize avinterface sz_vert sz_horiz  \
# avrid
# 1                 R1              D1.5           O       B        R
# 2                  U                D2           U       U        U
# 3                  U                D1           U       U        U
# 4                 R2                D1           I       M        R
# 5                 R2                D1           I       T        C
# ...              ...               ...         ...     ...      ...
# 504               R2                D2           I       T        L
# 505               R1              D1.5           O       T        U
# 506               R2                D2           O       T        C
# 507               R3                D3           O       T        C
# 508               R1                D2           O       T        L
#
#        sz_avgslope  sz_elev_m sz_aspect  term_elev_m  av_vert_m  \
# avrid
# 1                0          0       NaN            0          0
# 2                0          0       NaN            0          0
# 3                0          0       NaN            0          0
# 4                0          0       NaN            0          0
# 5                0          0       NaN            0          0
# ...            ...        ...       ...          ...        ...
# 504             38       2015         E         1760        255
# 505              0       1830        SW         1460        370
# 506             40       2075        SE         1646        429
# 507             40       2195        SE         1790        405
# 508             40       2135        SE         1400        735
#
#        crown_width_m  ch_max_cm  ch_min_cm  ch_diff_cm term_longpath  \
# avrid
# 1                  0          0          0           0            TK
# 2                  0          0          0           0            TK
# 3                  0          0          0           0            TR
# 4                  0          0          0           0            TK
# 5                  0          0          0           0            TK
# ...              ...        ...        ...         ...           ...
# 504                0          0          0           0            TK
# 505                0          0          0           0            TR
# 506                0          0          0           0            TK
# 507              245        150         40          95            MR
# 508                0          0          0           0            MR
#
#       term_shortPath term_detail term_moist  deb_rail  deb_rail_w  deb_rail_d  \
# avrid
# 1                NaN         NaN        NaN     False         0.0         0.0
# 2                NaN         NaN        NaN     False         0.0         0.0
# 3                NaN         NaN        NaN     False         0.0         0.0
# 4                NaN         NaN        NaN     False         0.0         0.0
# 5                NaN         NaN        NaN     False         0.0         0.0
# ...              ...         ...        ...       ...         ...         ...
# 504                -           U          U     False         0.0         0.0
# 505                -           U          W     False         0.0         0.0
# 506                -           U          W     False         0.0         0.0
# 507                -           U          U     False         0.0         0.0
# 508                -           U          W     False         0.0         0.0
#
#        deb_hwy  deb_hwy_w  deb_hwy_d      time                  dt  \
# avrid
# 1        False        0.0        0.0  12:45:00 2012-03-26 12:45:00
# 2        False        0.0        0.0  08:30:00 2012-03-16 08:30:00
# 3        False        0.0        0.0  08:34:00 2012-03-16 08:34:00
# 4        False        0.0        0.0  14:50:00 2012-03-10 14:50:00
# 5        False        0.0        0.0  14:54:00 2012-03-10 14:54:00
# ...        ...        ...        ...       ...                 ...
# 504      False        0.0        0.0  05:04:00 2022-03-01 05:04:00
# 505      False        0.0        0.0  13:30:00 2022-03-23 13:30:00
# 506      False        0.0        0.0  13:30:00 2022-03-23 13:30:00
# 507      False        0.0        0.0  18:00:00 2022-03-23 18:00:00
# 508      False        0.0        0.0  14:35:00 2022-03-27 14:35:00
#
#                     wx_dt  temp  dew_pt    rH  heat_idx  wind_chill wind_dir  \
# avrid
# 1                     NaT   NaN     NaN   NaN       NaN         NaN      NaN
# 2                     NaT   NaN     NaN   NaN       NaN         NaN      NaN
# 3                     NaT   NaN     NaN   NaN       NaN         NaN      NaN
# 4                     NaT   NaN     NaN   NaN       NaN         NaN      NaN
# 5                     NaT   NaN     NaN   NaN       NaN         NaN      NaN
# ...                   ...   ...     ...   ...       ...         ...      ...
# 504   2022-03-01 05:00:00  31.0    30.0  96.0       NaN         NaN       NW
# 505   2022-03-23 13:00:00  38.0    31.0  77.0       NaN         NaN      WNW
# 506   2022-03-23 13:00:00  38.0    31.0  77.0       NaN         NaN      WNW
# 507   2022-03-23 18:00:00  48.0    32.0  53.0       NaN         NaN       SW
# 508   2022-03-27 14:00:00  48.0    26.0  43.0       NaN         NaN        W
#
#       wind_spd  hr_precip  snow_depth  snowfall_3hr  snowfall_6hr  \
# avrid
# 1          NaN        NaN         NaN           NaN           NaN
# 2          NaN        NaN         NaN           NaN           NaN
# 3          NaN        NaN         NaN           NaN           NaN
# 4          NaN        NaN         NaN           NaN           NaN
# 5          NaN        NaN         NaN           NaN           NaN
# ...        ...        ...         ...           ...           ...
# 504       4G15        NaN        79.8           0.0           0.2
# 505       3G11        NaN        85.3           0.0           0.0
# 506       3G11        NaN        85.3           0.0           0.0
# 507       4G12        NaN        83.4           0.0           0.0
# 508       3G10        NaN        77.0           0.0           0.0
#
#        snowfall_24hr   site  year  sea_lvl_press  sta_press  \
# avrid
# 1                NaN    NaN   NaN            NaN        NaN
# 2                NaN    NaN   NaN            NaN        NaN
# 3                NaN    NaN   NaN            NaN        NaN
# 4                NaN    NaN   NaN            NaN        NaN
# 5                NaN    NaN   NaN            NaN        NaN
# ...              ...    ...   ...            ...        ...
# 504             11.1  S11MT  2022            NaN        NaN
# 505              0.0  S11MT  2022            NaN        NaN
# 506              0.0  S11MT  2022            NaN        NaN
# 507              0.0  S11MT  2022            NaN        NaN
# 508              0.0  S11MT  2022            NaN        NaN
#
#        altimeter_setting  solar_radiation pct_possible
# avrid
# 1                    NaN              NaN          NaN
# 2                    NaN              NaN          NaN
# 3                    NaN              NaN          NaN
# 4                    NaN              NaN          NaN
# 5                    NaN              NaN          NaN
# ...                  ...              ...          ...
# 504                  NaN              NaN          NaN
# 505                  NaN              NaN          NaN
# 506                  NaN              NaN          NaN
# 507                  NaN              NaN          NaN
# 508                  NaN              NaN          NaN
#
# [491 rows x 52 columns]

# %%
avywx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 1 to 508
# Data columns (total 52 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avpathid           491 non-null    object
#  1   avobsdate          491 non-null    datetime64[ns]
#  2   avobstime          491 non-null    object
#  3   avtype             485 non-null    object
#  4   avtriggertyp       455 non-null    float64
#  5   avtrigger          446 non-null    object
#  6   avrelativesize     474 non-null    object
#  7   avdestructivesize  441 non-null    object
#  8   avinterface        431 non-null    object
#  9   sz_vert            470 non-null    object
#  10  sz_horiz           453 non-null    object
#  11  sz_avgslope        491 non-null    int64
#  12  sz_elev_m          491 non-null    int64
#  13  sz_aspect          105 non-null    object
#  14  term_elev_m        491 non-null    int64
#  15  av_vert_m          491 non-null    int64
#  16  crown_width_m      491 non-null    int64
#  17  ch_max_cm          491 non-null    int64
#  18  ch_min_cm          491 non-null    int64
#  19  ch_diff_cm         491 non-null    int64
#  20  term_longpath      461 non-null    object
#  21  term_shortPath     326 non-null    object
#  22  term_detail        307 non-null    object
#  23  term_moist         378 non-null    object
#  24  deb_rail           491 non-null    bool
#  25  deb_rail_w         491 non-null    float64
#  26  deb_rail_d         491 non-null    float64
#  27  deb_hwy            491 non-null    bool
#  28  deb_hwy_w          491 non-null    float64
#  29  deb_hwy_d          491 non-null    float64
#  30  time               491 non-null    object
#  31  dt                 491 non-null    datetime64[ns]
#  32  wx_dt              89 non-null     datetime64[ns]
#  33  temp               89 non-null     float64
#  34  dew_pt             89 non-null     float64
#  35  rH                 89 non-null     float64
#  36  heat_idx           0 non-null      float64
#  37  wind_chill         28 non-null     float64
#  38  wind_dir           88 non-null     object
#  39  wind_spd           89 non-null     object
#  40  hr_precip          0 non-null      float64
#  41  snow_depth         89 non-null     float64
#  42  snowfall_3hr       89 non-null     float64
#  43  snowfall_6hr       89 non-null     float64
#  44  snowfall_24hr      87 non-null     float64
#  45  site               89 non-null     object
#  46  year               89 non-null     object
#  47  sea_lvl_press      0 non-null      float64
#  48  sta_press          0 non-null      float64
#  49  altimeter_setting  0 non-null      float64
#  50  solar_radiation    0 non-null      float64
#  51  pct_possible       0 non-null      object
# dtypes: bool(2), datetime64[ns](3), float64(19), int64(8), object(20)
# memory usage: 196.6+ KB

# %%
avywx.to_pickle('data-prep/pkl/avywx2.pkl')
