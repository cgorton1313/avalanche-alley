# %%
import pandas as pd
import numpy as np

# %%
data_obs_avy = pd.read_csv('../raw_data/aa/data_obs_avy.csv', index_col='avrid')

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

data_obs_avy
# Out:
#          avpathid   avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1          SHED10  2012-03-26  12:45:00     stein_01     WS           5.0
# 2        PATH1163  2012-03-16  08:30:00     stein_01      U           5.0
# 3           CURLY  2012-03-16  08:34:00     stein_01      U           5.0
# 4          SHED10  2012-03-10  14:50:00     stein_01     WL           5.0
# 5        INFINITY  2012-03-10  14:54:00     stein_01      L           5.0
# 6          SECOND  2012-03-05  11:45:00     stein_01     SS           5.0
# 7         BURNOUT  2012-03-03  01:30:00     stein_01     SS           5.0
# 8         SHED09L  2012-02-28  11:16:00     stein_01     SS           5.0
# 9        INFINITY  2012-02-28  11:09:00     dunda_01     SS           5.0
# 10         SHED09  2012-02-28  11:16:00     stein_01     HS           5.0
# 399       BURNOUT  2019-02-14  12:27:00     clark_01     SS           1.0
# 12       PATH1163  2012-02-22  12:40:00     stein_01     SS           5.0
# ...

# %%
data_obs_avy.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 491 entries, 1 to 508
# Data columns (total 38 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   avpathid           491 non-null    object
#  1   avobsdate          491 non-null    object
#  2   avobstime          491 non-null    object
#  3   avobserverid       491 non-null    object
#  4   avtype             485 non-null    object
#  5   avtriggertyp       455 non-null    float64
#  6   avtrigger          446 non-null    object
#  7   avrelativesize     474 non-null    object
#  8   avdestructivesize  441 non-null    object
#  9   avinterface        431 non-null    object
#  10  sz_vert            470 non-null    object
#  11  sz_horiz           453 non-null    object
#  12  sz_avgslope        491 non-null    int64
#  13  sz_elev_m          491 non-null    int64
#  14  sz_aspect          105 non-null    object
#  15  term_elev_m        491 non-null    int64
# ...

# %%
data_obs_avy.describe()
# Out:
#        avtriggertyp  sz_avgslope    sz_elev_m  term_elev_m    av_vert_m  \
# count    455.000000   491.000000   491.000000   491.000000   491.000000
# mean       4.725275     6.991853   947.716904   878.142566   200.945010
# std        0.976214    15.022430   960.703377   811.593260   320.930902
# min        1.000000     0.000000     0.000000     0.000000     0.000000
# 25%        5.000000     0.000000     0.000000     0.000000     0.000000
# 50%        5.000000     0.000000  1280.000000  1310.000000     0.000000
# 75%        5.000000     0.000000  1866.500000  1460.000000   344.500000
# max        5.000000    45.000000  5000.000000  4550.000000  2285.000000
#
#        crown_width_m   ch_max_cm   ch_min_cm  ch_diff_cm    deb_rail  \
# count     491.000000  491.000000  491.000000  491.000000  491.000000
# mean       32.059063   21.908350   12.639511   17.179226    0.077393
# std       117.026853   44.065139   27.149217   33.948046    0.267487
# ...

# %%
data_obs_avy.avobsdate.dtypes
# Out:
# dtype('O')

# %%
data_obs_avy['avobsdate'] =  pd.to_datetime(data_obs_avy['avobsdate'])

# %% [markdown]
# #### Citation: https://stackoverflow.com/questions/26763344/convert-pandas-column-to-datetime#:~:text=Use%20the%20pandas%20to_datetime%20function,the%20mentioned%20column%20to%20DateTime.

# %%
data_obs_avy.avobsdate.dtypes
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# #### Difference between dtype('<M8[ns]') and regular datetime object: https://stackoverflow.com/questions/29206612/difference-between-data-type-datetime64ns-and-m8ns

# %%
data_obs_avy['edcr_time'] =  pd.to_datetime(data_obs_avy['edcr_time'])
data_obs_avy.edcr_time.dtypes
# Out:
# dtype('<M8[ns]')

# %%
# data_obs_avy['eded_time'] =  pd.to_datetime(data_obs_avy['eded_time'])
# data_obs_avy.eded_time.dtypes

# %%
data_obs_avy.deb_hwy = data_obs_avy.deb_hwy.astype('bool')

# %%
data_obs_avy.deb_rail = data_obs_avy.deb_rail.astype('bool')

# %%
data_obs_avy
# Out:
#          avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1          SHED10 2012-03-26  12:45:00     stein_01     WS           5.0
# 2        PATH1163 2012-03-16  08:30:00     stein_01      U           5.0
# 3           CURLY 2012-03-16  08:34:00     stein_01      U           5.0
# 4          SHED10 2012-03-10  14:50:00     stein_01     WL           5.0
# 5        INFINITY 2012-03-10  14:54:00     stein_01      L           5.0
# 6          SECOND 2012-03-05  11:45:00     stein_01     SS           5.0
# 7         BURNOUT 2012-03-03  01:30:00     stein_01     SS           5.0
# 8         SHED09L 2012-02-28  11:16:00     stein_01     SS           5.0
# 9        INFINITY 2012-02-28  11:09:00     dunda_01     SS           5.0
# 10         SHED09 2012-02-28  11:16:00     stein_01     HS           5.0
# 399       BURNOUT 2019-02-14  12:27:00     clark_01     SS           1.0
# 12       PATH1163 2012-02-22  12:40:00     stein_01     SS           5.0
# ...

# %%
data_obs_avy.to_pickle('pkl/avy_obs.pkl')
