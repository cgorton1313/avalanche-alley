# %% [markdown]
# # Profiling avy_obs_pkl

# %%
import pandas as pd
import pandas_profiling

avy_obs = pd.read_pickle('pkl/avy_obs.pkl')
avy_obs
# Out:
#        avpathid  avobsdate avobstime avobserverid avtype  avtriggertyp  \
# avrid
# 1        SHED10 2012-03-26  12:45:00     stein_01     WS           5.0
# 2      PATH1163 2012-03-16  08:30:00     stein_01      U           5.0
# 3         CURLY 2012-03-16  08:34:00     stein_01      U           5.0
# 4        SHED10 2012-03-10  14:50:00     stein_01     WL           5.0
# 5      INFINITY 2012-03-10  14:54:00     stein_01      L           5.0
# ...         ...        ...       ...          ...    ...           ...
# 504     SHED07W 2022-03-01  05:04:00     clark_01     SS           5.0
# 505     AP1163H 2022-03-23  13:30:00     clark_01     WL           5.0
# 506      SHED10 2022-03-23  13:30:00     clark_01     WL           5.0
# 507     MCAMSER 2022-03-23  18:00:00     clark_01     HS           5.0
# 508    PATH1163 2022-03-27  14:35:00     clark_01     WL           5.0
#
#       avtrigger avrelativesize avdestructivesize avinterface  ... deb_hwy  \
# ...

# %%
profile = avy_obs.profile_report(title = 'Avalanche Observations Profiling')
profile.to_file(output_file='data-profiles/avy_obs-profile.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# # Profile Findings
#
# #### The following 18 columns have missing values:
#     avtype has 6 (1.2%) missing values
#     avtriggertyp has 36 (7.3%) missing values
#     avtrigger has 45 (9.2%) missing values
#     avrelativesize has 17 (3.5%) missing values
#     avdestructivesize has 50 (10.2%) missing values
#     avinterface has 60 (12.2%) missing values
#     sz_vert has 21 (4.3%) missing values
#     sz_horiz has 38 (7.7%) missing values
#     sz_aspect has 386 (78.6%) missing values
#     term_longpath has 30 (6.1%) missing values
#     term_shortPath has 165 (33.6%) missing values
#     term_detail has 184 (37.5%) missing values
#     term_moist has 113 (23.0%) missing values
#     avcomment has 129 (26.3%) missing values
#     edcr_user has 127 (25.9%) missing values
#     edcr_ip has 98 (20.0%) missing values
#     eded_user has 294 (59.9%) missing values
#     eded_ip has 293 (59.7%) missing values
